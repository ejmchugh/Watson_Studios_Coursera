# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Elizabeth McHugh**
#   Student

# %% [markdown]
# I am interested in learning data science because I am exploring what I can do with a degree in mathematics apart from teach or perform academic research.

# %% [markdown]
# ### This code will compute the square root of 3 to four decimal places.

# %%
import math
print("The square root of 3 is approximately:")
print(round(math.sqrt(3), 4))
# Out:
# The square root of 3 is approximately:
# 1.7321

# %% [markdown]
# - This is
# - A
#     + Bulleted
# - List
#
# ---
#
# ~~Vertical~~ Horizontal Rule
#
# ---
#
# 1. This is
# 2. A
#     + Numbered
# 3. List
